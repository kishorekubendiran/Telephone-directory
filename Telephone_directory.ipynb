# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorekubendiran/Telephone-directory/blob/main/Telephone_directory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# !pip install pymongo[srv]

import re
import pandas as pd
import pymongo
client = pymongo.MongoClient("mongodb+srv://kishorekubendiran:<password>@cluster0.tywig9w.mongodb.net/?retryWrites=true&w=majority")
db = client.Telephone
D=db.Directory
#db.Directory.drop()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.3.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)

# %%
print("_________________________________________________________________________\n")
print("                                Welcome")
print("                                   to")
print("                           Telephone Directory")
print("_________________________________________________________________________")
print("\n\n-------------------------------------------------------------------------")
print(">>>>>>>>>>>>>>>>>>>>>>>>>>>.....Main menu.....<<<<<<<<<<<<<<<<<<<<<<<<<<<")
print("-------------------------------------------------------------------------\n\n")
print("<> To create a new contact name---------------------------->enter '''1'''")  
print("<> To retrive (or) search a contact name or contact number->enter '''2'''") 
print("<> To delete a contact number------------------------------>enter '''3'''") 
print("<> To update a contact------------------------------------->enter '''4'''")
print("<> To display contact-------------------------------------->enter '''5'''\n\n")

def happy_home():
  press=input("Please enter here: ")
  if press=="1":
    new_contact()
  elif press=="2":
    search_contact()
  elif press=="3":
    delete_contact()
  elif press=="4":
    update_contact()
  elif press=="5":
    display_contact()
  else:
    print("_________________________________________________________________________\n")
    print("                  .....Please enter the vaild number.....                ")
    print("_________________________________________________________________________\n")
    happy_home()

def new_contact():
  print("\n\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>.....contact register page.....<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n\n")
  d={
      "_id":contact_name(), 
      "phone_number":phone_number(),
      "mail": mail_id(),
      "place":place(),
      "pincode":pincode()
      }
  D.insert_one(d)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("       .....Your contact details has been added successfully.....        ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def contact_name():
  i=0
  while(i==0):
    name=input("<> Enter your contact name: ")
    _name="[A-Z a-z \._-]{2,25}$"
    if D.find_one({'_id':{'$eq':name}}):
      print("_________________________________________________________________________\n")
      print("            .....The entered contact name already exists.....            ")
      print("                 .....Please enter a different name.....                 ")
      print("_________________________________________________________________________\n")
      i=0
    else:
      if re.match(_name,name):
        i=1
        if (contact_name is not None):
          return(name)
      else:
        i=0
        print("_________________________________________________________________________\n")
        print("                  .....Please enter a valid name.....                    ")
        print("_________________________________________________________________________\n")

def phone_number():
  i=0
  while(i==0):
    phone_number1=input("<> Enter your phone number: ")
    _phone_number="[123456789][0-9]{9}$"
    if D.find_one({'phone_number': {'$eq':phone_number1}}):
      print("_________________________________________________________________________\n")
      print("            .....The entered phone number already exists.....            ")
      print("             .....Please enter a different phone number.....             ")
      print("_________________________________________________________________________\n")
      i=0
    else:
      if re.match(_phone_number,phone_number1) and len(phone_number1)==10:
        i=1
        if (phone_number is not None):
          return(phone_number1)
      else:
        i=0
        print("_________________________________________________________________________\n")
        print("              .....Please enter the valid phone number.....              ")
        print("_________________________________________________________________________\n")

def mail_id():
  i=0
  while(i==0):
    mail=input("<> Enter your Email id    : ")
    _mail="^[a-z A-Z]+[\._]?[a-z A-Z 0-9 \._-]+[@]\w+[A-Z a-z]+[.][A-Z a-z]{2,3}$"
    if D.find_one({'mail': {'$eq':mail}}):
      print("_________________________________________________________________________\n")
      print("               .....The entered mail id already exists.....              ")
      print("                .....Please enter a different mail id.....               ")
      print("_________________________________________________________________________\n")
      i=0
    else:
      if re.match(_mail,mail):
        i=1
        if (mail_id is not None):
          return(mail)
      else:
        i=0
        print("_________________________________________________________________________\n")
        print("                .....Please enter the valid Email id.....                ")
        print("_________________________________________________________________________\n")

def place():
  i=0
  while(i==0):
    department=input("<> Enter your place       : ")
    _department="[A-Z a-z \._-]{2,25}$"
    if re.match(_department,department):
      i=1
      if (place is not None):
          return(department)
      else:
        i=0
        print("_________________________________________________________________________\n")
        print("                  .....Please enter the valid place.....                 ")
        print("_________________________________________________________________________\n")

def pincode():
  i=0
  while(i==0):
    pin=input("<> Enter 6 digit pincode  :")
    pin_="[0-9]{6}"
    if re.match(pin_,pin) and len(pin)==6:
      i=1
      if (pincode is not None):
        return(pin)
    else:
      i=0
      print("_________________________________________________________________________\n")
      print("                .....Please enter the correcrt pincode.....              ")
      print("_________________________________________________________________________\n")

def search_contact():
  print("\n\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>>.....contact search page.....<<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n\n")
  name1=input("<> Enter the name or mail ID or Mobile number:") 
  r={"$or":[{("_id"):(name1)},{("mail"):(name1)},{("phone_number"):(name1)}]}  
  for x in D.find(r):
    print("\n")
    print(x)
    print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
    print("                            .....THANK YOU.....                          ")
    print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def delete_contact():
  print("\n\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>>.....contact delete page.....<<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n\n")
  name1=input("<> Enter the name or mail ID or Mobile number: ") 
  r={"$or":[{("_id"):(name1)},{("mail"):(name1)},{("phone_number"):(name1)}]}  
  D.delete_one(r)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("      .....Your contact details has been deleted successfully.....       ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def update_name():
  i=0
  while(i==0):
    _name=input("\n<> Enter your contact name: ")
    if D.find_one({'_id':{'$eq':_name}}):
      i=1
      if (update_name is not None):
        return(_name)
    else:
      i=0
      print("_________________________________________________________________________\n")
      print("            .....The entered contact name does not match.....            ")
      print("              .....Please enter a existing contact name.....             ")
      print("_________________________________________________________________________")

def update_contact():
  print("\n\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>>.....contact update page.....<<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n\n")
  print("<> To update your phone number----------------------------->enter '''1'''")
  print("<> To update your mail id---------------------------------->enter '''2'''")
  print("<> To update your place------------------------------------>enter '''3'''")
  print("<> To update your pincode---------------------------------->enter '''4'''\n")
  enter=input("Please enter here: ")
  if enter=="1" or enter=="2" or enter=="3" or enter=="4":
    if enter=="1":
      update_phone_number()
    elif enter=="2":
      update_mail_id()
    elif enter=="3":
      update_place()
    elif enter=="4":
      update_pincode()
  else:
    print("_________________________________________________________________________\n")
    print("                  .....Please enter the vaild number.....                ")
    print("_________________________________________________________________________\n")
    update_contact()

def update_phone_number():
  query=update_name()
  update=phone_number()
  query_1={'_id':query}
  query_2={'$set':{"phone_number":update}}
  D.update_one(query_1,query_2)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("      .....Your contact details has been updated successfully.....       ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def update_mail_id():
  query=update_name()
  update=mail_id()
  query_1={'_id':query}
  query_2={'$set':{"mail":update}}
  D.update_one(query_1,query_2)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("      .....Your contact details has been updated successfully.....       ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def update_place():
  query=update_name()
  update=input("<> Enter what you want to change: ")
  query_1={'_id':query}
  query_2={'$set':{"place":update}}
  D.update_one(query_1,query_2)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("      .....Your contact details has been updated successfully.....       ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

def update_pincode():
  query=update_name()
  update=input("<> Enter what you want to change: ")
  query_1={'_id':query}
  query_2={'$set':{"pincode":update}}
  D.update_one(query_1,query_2)
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("      .....Your contact details has been updated successfully.....       ")
  print("                            .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")


def display_contact():
  print("\n\n-------------------------------------------------------------------------")
  print(">>>>>>>>>>>>>>>>>>>>>.....contact display page.....<<<<<<<<<<<<<<<<<<<<<<")
  print("-------------------------------------------------------------------------\n\n")
  mylist=D.find({},{"_id":1,"phone_number":1,"mail":1,'place':1,'pincode':1}).sort("_id")
  mylist=pd.DataFrame(mylist)
  print(mylist)
  #for i in mylist:
    #mylist
    
  print("\n_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_\n")
  print("                           .....THANK YOU.....                          ")
  print("_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_")

happy_home()
# Out:
# _________________________________________________________________________
#
#                                 Welcome
#                                    to
#                            Telephone Directory
# _________________________________________________________________________
#
#
# -------------------------------------------------------------------------
# >>>>>>>>>>>>>>>>>>>>>>>>>>>.....Main menu.....<<<<<<<<<<<<<<<<<<<<<<<<<<<
# -------------------------------------------------------------------------
#
#
# <> To create a new contact name---------------------------->enter '''1'''
# <> To retrive (or) search a contact name or contact number->enter '''2'''
# <> To delete a contact number------------------------------>enter '''3'''
# <> To update a contact------------------------------------->enter '''4'''
# <> To display contact-------------------------------------->enter '''5'''
#
#
# Please enter here: 5
#
#
# -------------------------------------------------------------------------
# >>>>>>>>>>>>>>>>>>>>>.....contact display page.....<<<<<<<<<<<<<<<<<<<<<<
# -------------------------------------------------------------------------
#
#
#                _id phone_number                mail     place pincode
# 0  Vijayalakshmi N   7502741016  yukeshan@gmail.com      ooty  090909
# 1          kishore   9080880497    kishore@gmil.com     polur  606803
# 2       kubendiran   1234567890   kishore@gmail.com  kandilli  123456
#
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
#
#                            .....THANK YOU.....
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
